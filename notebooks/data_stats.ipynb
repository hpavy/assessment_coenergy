# %%
from coenergy.util_assessement import load_simulation_data

data = load_simulation_data("../data/")

print("indoor_temperature:", data.indoor_temperature.shape)
print("indoor_U:", data.indoor_U.shape)
print("HLC:", data.HLC.shape)
print("Hb:", data.Hb.shape, "labels:", data.Hb_labels)
print("CDT:", data.CDT.shape)
print("solicitation:", data.solicitation.shape, "fields:", data.solicitation_field_names)
# Out:
# indoor_temperature: torch.Size([2000000, 600])
# indoor_U: torch.Size([2000000, 600])
# HLC: torch.Size([2000000])
# Hb: torch.Size([2000000, 4]) labels: ['TEMP_MIT_3', 'TEMP_EXT', 'TEMP_MIT_2', 'TEMP_MIT_4']
# CDT: torch.Size([2000000, 3])
# solicitation: torch.Size([2000000, 12]) fields: ['max_power_wat', 'start_amplitude_wat', 'end_amplitude_wat', 'start_period_hours', 'end_period_hours', 'transition_speed', 'phase_shift', 'average_fluctuation_wat', 'prbs_min_duration_hours', 'prbs_max_duration_hours', 'prbs_probability_on', 'prbs_seed']

# %%
data.Hb_labels
# Out:
# ['TEMP_MIT_3', 'TEMP_EXT', 'TEMP_MIT_2', 'TEMP_MIT_4']

# %%
data.indoor_temperature.shape
# Out:
# torch.Size([2000000, 600])
